# %% [markdown]
# # 03: ClinVar Clinical Variant Validation & ROC-AUC Benchmark
#
# This notebook benchmarks the three computational predictors (AlphaMissense, SIFT, PolyPhen-2) against clinically verified human missense variants from ClinVar (**Figure 6 & Table 2**).
#
# ### Evaluated Metrics:
# - ROC Curves & Area Under the Curve (AUC)
# - Pathogenic vs. Benign variant distribution across transmembrane helices

# %%
import sys
from pathlib import Path
import pandas as pd

src_path = Path.cwd().parent / 'src'
if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

import clinvar_benchmark as cb

# %% [markdown]
# ## 1. Load ClinVar Variants (Table 2)

# %%
#clinvar_csv = Path.cwd().parent / 'data' / 'clinvar' / 'glut_clinvar_variants.csv'
clinvar_csv = Path.cwd().parent / 'data' / 'clinvar' / 'united_clinvar.csv'

df = pd.read_csv(clinvar_csv)
display(df.head())
# Out:
#   Protein Protein change Germline classification  Position  Class_num  \
# 0  GLUT10          I537V                  Benign       537        0.0
# 1  GLUT10          T518A                  Benign       518        0.0
# 2  GLUT10          K514R                  Benign       514        0.0
# 3  GLUT10          A385G                  Benign       385        0.0
# 4  GLUT10          S520N    Benign/Likely benign       520        0.0
#
#    AlphaMissense  PolyPhen-2      SIFT
# 0           0.11       0.037  0.158421
# 1           0.08       0.135  0.201053
# 2           0.17       0.255  0.173158
# 3           0.11       0.319  0.335263
# 4           0.10       0.246  0.413158
# Germline classification   Benign   Benign/Likely benign   Pathogenic  \
# Protein
# GLUT1                        1.0                    2.0         46.0
# GLUT10                       4.0                    4.0          3.0
# GLUT2                        0.0                    0.0          0.0
# GLUT5                        0.0                    0.0          0.0
# GLUT6                        0.0                    0.0          0.0
# GLUT7                        0.0                    0.0          0.0
# GLUT8                        0.0                    0.0          0.0
# GLUT9                       17.0                    6.0          0.0
#
# Germline classification   Pathogenic/Likely pathogenic  Benign  \
# Protein
# GLUT1                                             25.0     0.0
# GLUT10                                             7.0     0.0
# GLUT2                                              0.0     7.0
# GLUT5                                              0.0     2.0
# GLUT6                                              0.0     2.0
# GLUT7                                              0.0     2.0
# GLUT8                                              0.0     2.0
# GLUT9                                              2.0     0.0
#
# Germline classification  Benign/Likely benign  Pathogenic  \
# Protein
# GLUT1                                     0.0         0.0
# GLUT10                                    0.0         0.0
# GLUT2                                     2.0         5.0
# GLUT5                                     0.0         0.0
# GLUT6                                     0.0         0.0
# GLUT7                                     0.0         0.0
# GLUT8                                     0.0         0.0
# GLUT9                                     0.0         0.0
#
# Germline classification  Pathogenic/Likely pathogenic
# Protein
# GLUT1                                             0.0
# GLUT10                                            0.0
# GLUT2                                             3.0
# GLUT5                                             0.0
# GLUT6                                             0.0
# GLUT7                                             0.0
# GLUT8                                             0.0
# GLUT9                                             0.0

# %% [markdown]
# ## 2. Execute ROC-AUC Benchmark & Generate Figures 6B and 6C

# %%
fig_dir = Path.cwd().parent / 'results' / 'figures'
aucs = cb.run_clinvar_benchmark(clinvar_csv, fig_dir)
# Out:
# Loaded 142 ClinVar variants across 8 GLUT proteins.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\domin\anaconda3\envs\glut_pathogenicity\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'clinical_significance'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 2
#       1 fig_dir = Path.cwd().parent / 'results' / 'figures'
# ----> 2 aucs = cb.run_clinvar_benchmark(clinvar_csv, fig_dir)
#
# File c:\Users\domin\Desktop\GLUT_pathogenicity_analysis\src\clinvar_benchmark.py:23, in run_clinvar_benchmark(data_csv, output_dir)
#      21 df = pd.read_csv(data_csv)
#      22 print(f"Loaded {len(df)} ClinVar variants across {df['Protein'].nunique()} GLUT proteins.")
# ---> 23 print("Class breakdown:\n", df["clinical_significance"].value_counts())
#      25 # Binary label: Pathogenic = 1, Benign = 0
#      26 y_true = (df["clinical_significance"].str.lower().str.contains("pathogenic")).astype(int)
#
# File c:\Users\domin\anaconda3\envs\glut_pathogenicity\lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File c:\Users\domin\anaconda3\envs\glut_pathogenicity\lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'clinical_significance'
