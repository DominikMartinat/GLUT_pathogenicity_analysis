# %% [markdown]
# # 02: DALI Structural Alignment & Transmembrane Helix Pathogenicity Profile
#
# This notebook aligns the 14 GLUT structures using DALI distance-matrix pairwise alignments and overlays residue-level AlphaMissense pathogenicity scores (**Figure 5**).

# %%
import sys
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

src_path = Path.cwd().parent / 'src'
if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

import alignment as ali

# %% [markdown]
# ## 1. Load Transmembrane Helix Pathogenicity Matrix (Figure 5C)

# %%
excel_path = Path.cwd().parent / 'statistics' / 'AlphaMissense hodnoty - per protein_helix.xlsx'
if excel_path.exists():
    helix_df = pd.read_excel(excel_path, sheet_name='glut vsechny')
    display(helix_df.head(15))
else:
    print('Excel file not found')
